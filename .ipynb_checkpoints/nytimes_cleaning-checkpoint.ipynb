# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import openai

# %%
nyt = pd.read_csv("nyt_full.tsv", sep = '\t')
nyt.head()
# Out:
#    year        week  rank  title_id                      title  \
# 0  1931  1931-10-12     1      6477       THE TEN COMMANDMENTS
# 1  1931  1931-10-12     2      1808           FINCHE'S FORTUNE
# 2  1931  1931-10-12     3      5304             THE GOOD EARTH
# 3  1931  1931-10-12     4      4038        SHADOWS ON THE ROCK
# 4  1931  1931-10-12     5      3946  SCARMOUCHE THE KING MAKER
#
#              author
# 0   Warwick Deeping
# 1  Mazo de la Roche
# 2     Pearl S. Buck
# 3      Willa Cather
# 4   Rafael Sabatini

# %%
nyt.author.nunique()
# Out:
# 2210

# %%
print(nyt.author)
# Out:
# 0                        Warwick Deeping
# 1                       Mazo de la Roche
# 2                          Pearl S. Buck
# 3                           Willa Cather
# 4                        Rafael Sabatini
#                       ...
# 60381                             Halsey
# 60382                       Brit Bennett
# 60383                        Delia Owens
# 60384                    Fredrik Backman
# 60385    Clive Cussler and Boyd Morrison
# Name: author, Length: 60386, dtype: object

# %%
# replace written & illustrated by 
nyt.author = nyt.author.replace("written and illustrated by ","", regex = True)

# %% [markdown]
# ## separate complicated entries

# %%
#if there is a preposition, there's complication
nyt.author = nyt.author.replace(" And "," and ", regex = True)
nyt['problem'] = nyt.author.str.contains(' and | with | by ', regex = True, case = False)
print("how many problem entries", nyt.problem.sum())
print(nyt.problem.sum()/len(nyt))

# new dataframe with just problems
nyt_review = nyt[nyt.problem == True]
print("how many unique problems", len(nyt_review.author.unique()))

#new dataframe without problems 
nyt_single = nyt[nyt.problem == False]
nyt_single.to_csv('nyt_single_authors.csv', index=False)
# Out:
# how many problem entries 2416
# 0.04000927367270559
# how many unique problems 189

# %% [raw]
# # editors
# #has_edited = nyt_review.author.str.contains('edited', regex = True, case = False)
# nyt_review['edited'] = nyt_review.author.str.contains('edited', regex = True, case = False)
# nyt_review.edited.sum()
#
# # new dataframe with just editors
# nyt_edited = nyt_review[nyt_review.edited == True]
# print(nyt_edited.author.unique())

# %%
# if there's an author with editor, remove editor, else treat editor as author 
nyt_review.author = nyt_review.author.replace(", edited by ",". Edited by ", regex = True)

#remove 'edited by ' and transfer rest of string to the 'author_alt' column
def resolve_editors(name):
    if 'dited ' in name:
        if name[:10] == 'edited by ':
            return name[10:]
        elif name[:10] != 'edited by ':
            substring = ('. Edited by ')
            return name.split(substring)[0]
    else: return name

nyt_review['author_alt'] = nyt_review.apply(lambda x: resolve_editors(x['author']), axis = 1)
# Out:
# /var/folders/p7/4d0x8hyj4mb4xypm89k57lrr0000gn/T/ipykernel_76972/3846054122.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nyt_review.author = nyt_review.author.replace(", edited by ",". Edited by ", regex = True)
# /var/folders/p7/4d0x8hyj4mb4xypm89k57lrr0000gn/T/ipykernel_76972/3846054122.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nyt_review['author_alt'] = nyt_review.apply(lambda x: resolve_editors(x['author']), axis = 1)

# %%
print(nyt_review['author_alt'].unique())
# Out:
# ['Charles Nordhoff and James N. Hall' 'Gideon Wyck'
#  'Charles Nordloff and James Norman Hall'
#  'Dennis Wheatley and J. H. Links' 'Somerset Maugham'
#  'Charles Nordhoff and James Norman Hall' 'Armin L. Robinson'
#  'Odell Shepard and Willard Shepard' '? by Isabel Bolton'
#  'Benedict Freedman and Nancy Freedman'
#  'Joseph Auslander and Audrey Wurdemann' 'James Street and James Childers'
#  'Charmian Clift and George Johnston' 'Harnett T. Kane and Victor Leclerc'
#  'Marrijane and Joseph Hayes' 'Dorothy Erskine and Patrick Dennis'
#  'William J. Lederer and Eugene Burdick'
#  'Arthur Quiller-Couch and Daphne du Maurier'
#  'Fletcher Knebel and Charles W. Bailey II'
#  'Eugene Burdick and Harvey Wheeler' 'Terry Southern and Mason Hoffenberg'
#  'Nicholas Meyer' 'J.D. Gilman and John Clive'
#  'Marvin Kalb and Ted Koppel'
#  'General Sir John Hackett and Other Top-ranking NATO Generals and Advisors'
#  'Arnaud de Borchgrave and Robert Moss'
#  'Larry Collins and Dominique Lapierre'
#  'Helen Van Slyke with James Elward' 'adapted by Joan D. Vinge'
#  'created by Bill Adler and written by Thomas Chastain'
#  'Robert Moss and Arnaud de Borchgrave'
#  'Whitley Strieber and James W. Kunetka' 'Stephen King and Peter Straub'
#  'Larry Niven and Jerry Pournelle'
#  'Patti Davis with Maureen Strange Foster' '! by Terry Brooks'
#  'Walter J. Boyne and Steven L. Thompson' 'compiled by Mary S. Lovell'
#  'Raymond Chandler and Robert B. Parker'
#  'Judith and Garfield Reeves-Stevens'
#  'Barry Lopez. Illustrated by Tom Pohrt'
#  'Michael Dorris and Louise Erdrich' 'Margaret Weis and Tracy Hickman'
#  'Arthur C. Clarke and Gentry Lee' 'Janet and Allan Ahlberg'
#  '? by Jimmy Buffett' 'adapted by Don Ferguson'
#  'Richard Marcinko and John Weisman' 'David and Leigh Eddings'
#  'William J. Bennett. Illustrated by Michael Hague'
#  'Tom Hegg. Illustrated by Warren Hanson'
#  'Alex Walsh. Illustrated by Jesse Clay'
#  'William Shatner with Judith and Garfield Reeves-Stevens'
#  'Margaret Mitchell'
#  'Dr. Seuss. Illustrated by Steve Johnson and Lou Fancher'
#  'William Shatner with Judith Reeves-Stevens and Garfield Reeves-Stevens'
#  '! by Jackie Collins' 'L. Ron Hubbard and Kevin J. Anderson'
#  '! by Fannie Flagg' 'Jamie Lee Curtis. Illustrated by Laura Cornell'
#  'Clement Moore. Illustrated by Jan Brett'
#  'Tim LaHaye and Jerry B. Jenkins'
#  'Maria Shriver. Illustrated by Sandra Speidel'
#  'John Updike and Katrina Kenison' 'L. Ron Hubbard and Dave Wolverton'
#  'Brian Herbert and Kevin J. Anderson' 'translated by Seamus Heaney'
#  'Mary Higgins Clark and Carol Higgins Clark'
#  'Rita Mae Brown and Sneaky Pie Brown' 'selected by Caroline Kennedy'
#  'Mario Puzo. Completed by Carol Gino' 'Joyce Reardon'
#  'James Patterson with Andrew Gross' 'Emma McLaughlin and Nicola Kraus'
#  'Hannah Crafts' 'Clive Cussler with Paul Kemprecos'
#  'James Patterson and Peter de Jonge' 'Oliver North with Joe Musser'
#  'James Patterson and Andrew Gross'
#  'Newt Gingrich and William R. Forstchen' 'Oliver North and Joe Musser'
#  'Nora Roberts and J. D. Robb' 'Tim LaHaye and Greg Dinallo'
#  '! by W. E. B. Griffin' '? by Susan Elizabeth Phillips'
#  '? by Sophie Kinsella' 'Ian Caldwell and Dustin Thomason'
#  'Douglas Preston and Lincoln Child' 'Tim LaHaye and Bob Phillips'
#  '? by Sidney Sheldon' 'Faye and Jonathan Kellerman'
#  'Clive Cussler and Dirk Cussler' 'James Patterson and Howard Roughan'
#  'Marcie Walsh with Michael Malone' 'James Patterson and Maxine Paetro'
#  '! by Terry Pratchett' 'W.E.B. Griffin and William E. Butterworth IV'
#  'Anne McCaffrey and Todd McCaffrey'
#  'James Patterson and Michael Ledwidge' 'J. R. R. Tolkien'
#  'W. E. B. Griffin and William E. Butterworth IV'
#  'Dick Francis and Felix Francis' 'Julia London with Alina Adams'
#  'Michael Reaves and Steve Perry'
#  'Amanda Goldberg and Ruthanna Khalighi Hopper'
#  'James Patterson and Gabrielle Charbonnet'
#  'Clive Cussler with Jack Du Brul' 'Iris Johansen and Roy Johansen'
#  'Mary Ann Shaffer and Annie Barrows'
#  'Glenn Beck with Kevin Balfe and Jason Wright'
#  'Clive Cussler and Jack Du Brul' 'Clive Cussler and Paul Kemprecos'
#  'Guillermo del Toro and Chuck Hogan'
#  'James Patterson and Richard DiLallo'
#  'Clive Cussler with Grant Blackwood'
#  'Newt Gingrich, William R. Forstchen and Albert S. Hanser'
#  'Robert Jordan and Brandon Sanderson' 'Clive Cussler and Justin Scott'
#  'Charlaine Harris and Toni L. P. Kelner'
#  'James Patterson and Liza Marklund' 'Tom Clancy with Grant Blackwood'
#  'Anders Roslund and Borge Hellstrom' 'Tom Clancy and Grant Blackwood'
#  'James Patterson and Neil McMahon' 'Tom Clancy with Peter Telep'
#  'James Patterson and Marshall Karp' 'Clive Cussler and Graham Brown'
#  'Michael Crichton and Richard Preston' 'Tom Clancy with Mark Greaney'
#  'Janet Evanovich and Dorien Kelly' 'James Patterson and Mark Sullivan'
#  'James Patterson and David Ellis' 'Bethenny Frankel with Eve Adamson'
#  'Terry Pratchett and Stephen Baxter'
#  'Orson Scott Card and Aaron Johnston' 'Clive Cussler and Thomas Perry'
#  'Glenn Beck with Harriet Parke' 'James Rollins and Rebecca Cantrell'
#  'Janet Evanovich and Lee Goldberg' 'Glenn Beck with Jack Henderson'
#  'Catherine Coulter and J.\u2009T. Ellison'
#  'Robert Kirkman and Jay Bonansinga' 'Robert B. Parker with Helen Brann'
#  'James Patterson and Emily Raymond' 'James Rollins and Grant Blackwood'
#  'George R. R. Martin and Gardner Dozois'
#  'Clive Cussler and Russell Blake'
#  'Jonathan Kellerman and Jesse Kellerman'
#  'Mary Higgins Clark and Alafair Burke'
#  'James Patterson and Peter De Jonge' 'Clive Cussler and Boyd Morrison'
#  'Janet Evanovich and Phoef Sutton' 'Lucia Berlin'
#  'Catherine Coulter and J.T. Ellison' 'Vince Flynn and Kyle Mills'
#  'John Sandford and Ctein' 'Joseph Fink and Jeffrey Cranor'
#  'Brad Meltzer and Tod Goldberg' 'Stuart Woods and Parnell Hall'
#  'Clive Cussler and Robin Burcell'
#  'W.E.B. Griffin and William E. Butterworth'
#  'James Patterson and Candice Fox'
#  'James Patterson and Emily Raymond with Jill Dembowski'
#  'Catherine Coulter and J. T. Ellison'
#  'James Patterson and Frank Constantini, Emily Raymond and Brian Sitts'
#  'James Patterson and Frank Costantini, Emily Raymond and Brian Sitts'
#  'Stephen King and Richard Chizmar' 'Neal Stephenson and Nicole Galland'
#  'Elizabeth Peters and Joan Hess' 'James Patterson and James O. Born'
#  'Stephen King and Owen King' 'Greer Hendricks and Sarah Pekkanen'
#  'Guillermo del Toro and Daniel Kraus' 'Bill Clinton and James Patterson'
#  'James Patterson and Andrew Bourelle' 'James Patterson and Nancy Allen'
#  'Khaled Hosseini. Illustrated by Dan Williams'
#  'James Patterson and Max DiLallo' 'James Patterson with Max DiLallo'
#  'James Patterson and Brendan DuBois'
#  'Janet Evanovich and Peter Evanovich'
#  'Mark Greaney and Hunter Ripley Rawlings IV'
#  'Nelson DeMille and Alex DeMille' 'Jim Carrey and Dana Vachon'
#  'James Patterson and Chris Tebbetts' 'James Patterson and J.D. Barker'
#  'Lee Child and Andrew Child' 'James Patterson and Shan Serafin']

# %%
def resolve_illustrators(name):
    substring = ('. Illustrated by ')
    return name.split(substring)[0]
    
nyt_review['author_alt'] = nyt_review.apply(lambda x: resolve_illustrators(x['author_alt']), axis = 1)
nyt_review.author_alt.unique()
# Out:
# /var/folders/p7/4d0x8hyj4mb4xypm89k57lrr0000gn/T/ipykernel_76972/3184937616.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nyt_review['author_alt'] = nyt_review.apply(lambda x: resolve_illustrators(x['author_alt']), axis = 1)
# array(['Charles Nordhoff and James N. Hall', 'Gideon Wyck',
#        'Charles Nordloff and James Norman Hall',
#        'Dennis Wheatley and J. H. Links', 'Somerset Maugham',
#        'Charles Nordhoff and James Norman Hall', 'Armin L. Robinson',
#        'Odell Shepard and Willard Shepard', '? by Isabel Bolton',
#        'Benedict Freedman and Nancy Freedman',
#        'Joseph Auslander and Audrey Wurdemann',
#        'James Street and James Childers',
#        'Charmian Clift and George Johnston',
#        'Harnett T. Kane and Victor Leclerc', 'Marrijane and Joseph Hayes',
#        'Dorothy Erskine and Patrick Dennis',
#        'William J. Lederer and Eugene Burdick',
#        'Arthur Quiller-Couch and Daphne du Maurier',
#        'Fletcher Knebel and Charles W. Bailey II',
#        'Eugene Burdick and Harvey Wheeler',
#        'Terry Southern and Mason Hoffenberg', 'Nicholas Meyer',
#        'J.D. Gilman and John Clive', 'Marvin Kalb and Ted Koppel',
#        'General Sir John Hackett and Other Top-ranking NATO Generals and Advisors',
#        'Arnaud de Borchgrave and Robert Moss',
#        'Larry Collins and Dominique Lapierre',
#        'Helen Van Slyke with James Elward', 'adapted by Joan D. Vinge',
#        'created by Bill Adler and written by Thomas Chastain',
#        'Robert Moss and Arnaud de Borchgrave',
#        'Whitley Strieber and James W. Kunetka',
#        'Stephen King and Peter Straub', 'Larry Niven and Jerry Pournelle',
#        'Patti Davis with Maureen Strange Foster', '! by Terry Brooks',
#        'Walter J. Boyne and Steven L. Thompson',
#        'compiled by Mary S. Lovell',
#        'Raymond Chandler and Robert B. Parker',
#        'Judith and Garfield Reeves-Stevens', 'Barry Lopez',
#        'Michael Dorris and Louise Erdrich',
#        'Margaret Weis and Tracy Hickman',
#        'Arthur C. Clarke and Gentry Lee', 'Janet and Allan Ahlberg',
#        '? by Jimmy Buffett', 'adapted by Don Ferguson',
#        'Richard Marcinko and John Weisman', 'David and Leigh Eddings',
#        'William J. Bennett', 'Tom Hegg', 'Alex Walsh',
#        'William Shatner with Judith and Garfield Reeves-Stevens',
#        'Margaret Mitchell', 'Dr. Seuss',
#        'William Shatner with Judith Reeves-Stevens and Garfield Reeves-Stevens',
#        '! by Jackie Collins', 'L. Ron Hubbard and Kevin J. Anderson',
#        '! by Fannie Flagg', 'Jamie Lee Curtis', 'Clement Moore',
#        'Tim LaHaye and Jerry B. Jenkins', 'Maria Shriver',
#        'John Updike and Katrina Kenison',
#        'L. Ron Hubbard and Dave Wolverton',
#        'Brian Herbert and Kevin J. Anderson',
#        'translated by Seamus Heaney',
#        'Mary Higgins Clark and Carol Higgins Clark',
#        'Rita Mae Brown and Sneaky Pie Brown',
#        'selected by Caroline Kennedy',
#        'Mario Puzo. Completed by Carol Gino', 'Joyce Reardon',
#        'James Patterson with Andrew Gross',
#        'Emma McLaughlin and Nicola Kraus', 'Hannah Crafts',
#        'Clive Cussler with Paul Kemprecos',
#        'James Patterson and Peter de Jonge',
#        'Oliver North with Joe Musser', 'James Patterson and Andrew Gross',
#        'Newt Gingrich and William R. Forstchen',
#        'Oliver North and Joe Musser', 'Nora Roberts and J. D. Robb',
#        'Tim LaHaye and Greg Dinallo', '! by W. E. B. Griffin',
#        '? by Susan Elizabeth Phillips', '? by Sophie Kinsella',
#        'Ian Caldwell and Dustin Thomason',
#        'Douglas Preston and Lincoln Child', 'Tim LaHaye and Bob Phillips',
#        '? by Sidney Sheldon', 'Faye and Jonathan Kellerman',
#        'Clive Cussler and Dirk Cussler',
#        'James Patterson and Howard Roughan',
#        'Marcie Walsh with Michael Malone',
#        'James Patterson and Maxine Paetro', '! by Terry Pratchett',
#        'W.E.B. Griffin and William E. Butterworth IV',
#        'Anne McCaffrey and Todd McCaffrey',
#        'James Patterson and Michael Ledwidge', 'J. R. R. Tolkien',
#        'W. E. B. Griffin and William E. Butterworth IV',
#        'Dick Francis and Felix Francis', 'Julia London with Alina Adams',
#        'Michael Reaves and Steve Perry',
#        'Amanda Goldberg and Ruthanna Khalighi Hopper',
#        'James Patterson and Gabrielle Charbonnet',
#        'Clive Cussler with Jack Du Brul',
#        'Iris Johansen and Roy Johansen',
#        'Mary Ann Shaffer and Annie Barrows',
#        'Glenn Beck with Kevin Balfe and Jason Wright',
#        'Clive Cussler and Jack Du Brul',
#        'Clive Cussler and Paul Kemprecos',
#        'Guillermo del Toro and Chuck Hogan',
#        'James Patterson and Richard DiLallo',
#        'Clive Cussler with Grant Blackwood',
#        'Newt Gingrich, William R. Forstchen and Albert S. Hanser',
#        'Robert Jordan and Brandon Sanderson',
#        'Clive Cussler and Justin Scott',
#        'Charlaine Harris and Toni L. P. Kelner',
#        'James Patterson and Liza Marklund',
#        'Tom Clancy with Grant Blackwood',
#        'Anders Roslund and Borge Hellstrom',
#        'Tom Clancy and Grant Blackwood',
#        'James Patterson and Neil McMahon', 'Tom Clancy with Peter Telep',
#        'James Patterson and Marshall Karp',
#        'Clive Cussler and Graham Brown',
#        'Michael Crichton and Richard Preston',
#        'Tom Clancy with Mark Greaney', 'Janet Evanovich and Dorien Kelly',
#        'James Patterson and Mark Sullivan',
#        'James Patterson and David Ellis',
#        'Bethenny Frankel with Eve Adamson',
#        'Terry Pratchett and Stephen Baxter',
#        'Orson Scott Card and Aaron Johnston',
#        'Clive Cussler and Thomas Perry', 'Glenn Beck with Harriet Parke',
#        'James Rollins and Rebecca Cantrell',
#        'Janet Evanovich and Lee Goldberg',
#        'Glenn Beck with Jack Henderson',
#        'Catherine Coulter and J.\u2009T. Ellison',
#        'Robert Kirkman and Jay Bonansinga',
#        'Robert B. Parker with Helen Brann',
#        'James Patterson and Emily Raymond',
#        'James Rollins and Grant Blackwood',
#        'George R. R. Martin and Gardner Dozois',
#        'Clive Cussler and Russell Blake',
#        'Jonathan Kellerman and Jesse Kellerman',
#        'Mary Higgins Clark and Alafair Burke',
#        'James Patterson and Peter De Jonge',
#        'Clive Cussler and Boyd Morrison',
#        'Janet Evanovich and Phoef Sutton', 'Lucia Berlin',
#        'Catherine Coulter and J.T. Ellison', 'Vince Flynn and Kyle Mills',
#        'John Sandford and Ctein', 'Joseph Fink and Jeffrey Cranor',
#        'Brad Meltzer and Tod Goldberg', 'Stuart Woods and Parnell Hall',
#        'Clive Cussler and Robin Burcell',
#        'W.E.B. Griffin and William E. Butterworth',
#        'James Patterson and Candice Fox',
#        'James Patterson and Emily Raymond with Jill Dembowski',
#        'Catherine Coulter and J. T. Ellison',
#        'James Patterson and Frank Constantini, Emily Raymond and Brian Sitts',
#        'James Patterson and Frank Costantini, Emily Raymond and Brian Sitts',
#        'Stephen King and Richard Chizmar',
#        'Neal Stephenson and Nicole Galland',
#        'Elizabeth Peters and Joan Hess',
#        'James Patterson and James O. Born', 'Stephen King and Owen King',
#        'Greer Hendricks and Sarah Pekkanen',
#        'Guillermo del Toro and Daniel Kraus',
#        'Bill Clinton and James Patterson',
#        'James Patterson and Andrew Bourelle',
#        'James Patterson and Nancy Allen', 'Khaled Hosseini',
#        'James Patterson and Max DiLallo',
#        'James Patterson with Max DiLallo',
#        'James Patterson and Brendan DuBois',
#        'Janet Evanovich and Peter Evanovich',
#        'Mark Greaney and Hunter Ripley Rawlings IV',
#        'Nelson DeMille and Alex DeMille', 'Jim Carrey and Dana Vachon',
#        'James Patterson and Chris Tebbetts',
#        'James Patterson and J.D. Barker', 'Lee Child and Andrew Child',
#        'James Patterson and Shan Serafin'], dtype=object)

# %%
#some custom cleaning
#typo in name
nyt_review.author_alt = nyt_review.author_alt.replace("Charles Nordloff","Charles Nordhoff", regex = True)
nyt_review.author_alt = nyt_review.author_alt.replace("William Shatner with Judith$","William Shatner with Judith Reeves-Stevens", regex = True)
nyt_review.author_alt = nyt_review.author_alt.replace("Constantini","Costantini", regex = True)
nyt_review.author_alt = nyt_review.author_alt.replace("J. T. Ellison","J.T. Ellison", regex = True)
# Out:
# /var/folders/p7/4d0x8hyj4mb4xypm89k57lrr0000gn/T/ipykernel_76972/1334316233.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nyt_review.author_alt = nyt_review.author_alt.replace("Charles Nordloff","Charles Nordhoff", regex = True)
# /var/folders/p7/4d0x8hyj4mb4xypm89k57lrr0000gn/T/ipykernel_76972/1334316233.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nyt_review.author_alt = nyt_review.author_alt.replace("William Shatner with Judith$","William Shatner with Judith Reeves-Stevens", regex = True)
# /var/folders/p7/4d0x8hyj4mb4xypm89k57lrr0000gn/T/ipykernel_76972/1334316233.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nyt_review.author_alt = nyt_review.author_alt.replace("Constantini","Costantini", regex = True)
# /var/folders/p7/4d0x8hyj4mb4xypm89k57lrr0000gn/T/ipykernel_76972/1334316233.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nyt_review.author_alt = nyt_review.author_alt.replace("J. T. Ellison","J.T. Ellison", regex = True)

# %%
def split_two_authors(name):
    substring1 = (' and ')
    substring2 = (' with ')
    if substring1 in name:
        first_author = name.split(substring1)[0]
        second_author = name.split(substring1)[1]
    elif substring2 in name:
        first_author = name.split(substring2)[0]
        second_author = name.split(substring2)[1]
    else:
        first_author = name
        second_author = np.nan
    return first_author, second_author

nyt_review[['author_1', 'author_2']] = nyt_review.apply(lambda x: split_two_authors(x['author_alt']), axis=1, result_type='expand')
# Out:
# /var/folders/p7/4d0x8hyj4mb4xypm89k57lrr0000gn/T/ipykernel_76972/78456444.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nyt_review[['author_1', 'author_2']] = nyt_review.apply(lambda x: split_two_authors(x['author_alt']), axis=1, result_type='expand')

# %%
nyt_review.author_1.unique()
# Out:
# array(['Charles Nordhoff', 'Gideon Wyck', 'Dennis Wheatley',
#        'Somerset Maugham', 'Armin L. Robinson', 'Odell Shepard',
#        '? by Isabel Bolton', 'Benedict Freedman', 'Joseph Auslander',
#        'James Street', 'Charmian Clift', 'Harnett T. Kane', 'Marrijane',
#        'Dorothy Erskine', 'William J. Lederer', 'Arthur Quiller-Couch',
#        'Fletcher Knebel', 'Eugene Burdick', 'Terry Southern',
#        'Nicholas Meyer', 'J.D. Gilman', 'Marvin Kalb',
#        'General Sir John Hackett', 'Arnaud de Borchgrave',
#        'Larry Collins', 'Helen Van Slyke', 'adapted by Joan D. Vinge',
#        'created by Bill Adler', 'Robert Moss', 'Whitley Strieber',
#        'Stephen King', 'Larry Niven', 'Patti Davis', '! by Terry Brooks',
#        'Walter J. Boyne', 'compiled by Mary S. Lovell',
#        'Raymond Chandler', 'Judith', 'Barry Lopez', 'Michael Dorris',
#        'Margaret Weis', 'Arthur C. Clarke', 'Janet', '? by Jimmy Buffett',
#        'adapted by Don Ferguson', 'Richard Marcinko', 'David',
#        'William J. Bennett', 'Tom Hegg', 'Alex Walsh', 'William Shatner',
#        'Margaret Mitchell', 'Dr. Seuss', '! by Jackie Collins',
#        'L. Ron Hubbard', '! by Fannie Flagg', 'Jamie Lee Curtis',
#        'Clement Moore', 'Tim LaHaye', 'Maria Shriver', 'John Updike',
#        'Brian Herbert', 'translated by Seamus Heaney',
#        'Mary Higgins Clark', 'Rita Mae Brown',
#        'selected by Caroline Kennedy',
#        'Mario Puzo. Completed by Carol Gino', 'Joyce Reardon',
#        'James Patterson', 'Emma McLaughlin', 'Hannah Crafts',
#        'Clive Cussler', 'Oliver North', 'Newt Gingrich', 'Nora Roberts',
#        '! by W. E. B. Griffin', '? by Susan Elizabeth Phillips',
#        '? by Sophie Kinsella', 'Ian Caldwell', 'Douglas Preston',
#        '? by Sidney Sheldon', 'Faye', 'Marcie Walsh',
#        '! by Terry Pratchett', 'W.E.B. Griffin', 'Anne McCaffrey',
#        'J. R. R. Tolkien', 'W. E. B. Griffin', 'Dick Francis',
#        'Julia London', 'Michael Reaves', 'Amanda Goldberg',
#        'Iris Johansen', 'Mary Ann Shaffer', 'Glenn Beck with Kevin Balfe',
#        'Guillermo del Toro', 'Newt Gingrich, William R. Forstchen',
#        'Robert Jordan', 'Charlaine Harris', 'Tom Clancy',
#        'Anders Roslund', 'Michael Crichton', 'Janet Evanovich',
#        'Bethenny Frankel', 'Terry Pratchett', 'Orson Scott Card',
#        'Glenn Beck', 'James Rollins', 'Catherine Coulter',
#        'Robert Kirkman', 'Robert B. Parker', 'George R. R. Martin',
#        'Jonathan Kellerman', 'Lucia Berlin', 'Vince Flynn',
#        'John Sandford', 'Joseph Fink', 'Brad Meltzer', 'Stuart Woods',
#        'Neal Stephenson', 'Elizabeth Peters', 'Greer Hendricks',
#        'Bill Clinton', 'Khaled Hosseini', 'Mark Greaney',
#        'Nelson DeMille', 'Jim Carrey', 'Lee Child'], dtype=object)

# %%
#replace lost characters
nyt_review.author_1 = nyt_review.author_1.replace("! by ","", regex = True)
nyt_review.author_1 = nyt_review.author_1.replace("\? by ","", regex = True)

#replace other ways of saying editor
nyt_review.author_1 = nyt_review.author_1.replace("selected by ","", regex = True)
nyt_review.author_1 = nyt_review.author_1.replace("compiled by ","", regex = True)
nyt_review.author_1 = nyt_review.author_1.replace("translated by ","", regex = True)
nyt_review.author_1 = nyt_review.author_1.replace("adapted by ","", regex = True)
nyt_review.author_1 = nyt_review.author_1.replace("created by ","", regex = True)
#
nyt_review.author_1 = nyt_review.author_1.replace(". Completed by Carol Gino","", regex = True)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\?'
# <>:3: SyntaxWarning: invalid escape sequence '\?'
# /var/folders/p7/4d0x8hyj4mb4xypm89k57lrr0000gn/T/ipykernel_76972/3729342211.py:3: SyntaxWarning: invalid escape sequence '\?'
#   nyt_review.author_1 = nyt_review.author_1.replace("\? by ","", regex = True)
# /var/folders/p7/4d0x8hyj4mb4xypm89k57lrr0000gn/T/ipykernel_76972/3729342211.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nyt_review.author_1 = nyt_review.author_1.replace("! by ","", regex = True)
# /var/folders/p7/4d0x8hyj4mb4xypm89k57lrr0000gn/T/ipykernel_76972/3729342211.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nyt_review.author_1 = nyt_review.author_1.replace("\? by ","", regex = True)
# /var/folders/p7/4d0x8hyj4mb4xypm89k57lrr0000gn/T/ipykernel_76972/3729342211.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nyt_review.author_1 = nyt_review.author_1.replace("selected by ","", regex = True)
# /var/folders/p7/4d0x8hyj4mb4xypm89k57lrr0000gn/T/ipykernel_76972/3729342211.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nyt_review.author_1 = nyt_review.author_1.replace("compiled by ","", regex = True)
# /var/folders/p7/4d0x8hyj4mb4xypm89k57lrr0000gn/T/ipykernel_76972/3729342211.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nyt_review.author_1 = nyt_review.author_1.replace("translated by ","", regex = True)
# /var/folders/p7/4d0x8hyj4mb4xypm89k57lrr0000gn/T/ipykernel_76972/3729342211.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nyt_review.author_1 = nyt_review.author_1.replace("adapted by ","", regex = True)
# /var/folders/p7/4d0x8hyj4mb4xypm89k57lrr0000gn/T/ipykernel_76972/3729342211.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nyt_review.author_1 = nyt_review.author_1.replace("created by ","", regex = True)
# /var/folders/p7/4d0x8hyj4mb4xypm89k57lrr0000gn/T/ipykernel_76972/3729342211.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nyt_review.author_1 = nyt_review.author_1.replace(". Completed by Carol Gino","", regex = True)

# %%
nyt_review.author_1.unique()
# Out:
# array(['Charles Nordhoff', 'Gideon Wyck', 'Dennis Wheatley',
#        'Somerset Maugham', 'Armin L. Robinson', 'Odell Shepard',
#        'Isabel Bolton', 'Benedict Freedman', 'Joseph Auslander',
#        'James Street', 'Charmian Clift', 'Harnett T. Kane', 'Marrijane',
#        'Dorothy Erskine', 'William J. Lederer', 'Arthur Quiller-Couch',
#        'Fletcher Knebel', 'Eugene Burdick', 'Terry Southern',
#        'Nicholas Meyer', 'J.D. Gilman', 'Marvin Kalb',
#        'General Sir John Hackett', 'Arnaud de Borchgrave',
#        'Larry Collins', 'Helen Van Slyke', 'Joan D. Vinge', 'Bill Adler',
#        'Robert Moss', 'Whitley Strieber', 'Stephen King', 'Larry Niven',
#        'Patti Davis', 'Terry Brooks', 'Walter J. Boyne', 'Mary S. Lovell',
#        'Raymond Chandler', 'Judith', 'Barry Lopez', 'Michael Dorris',
#        'Margaret Weis', 'Arthur C. Clarke', 'Janet', 'Jimmy Buffett',
#        'Don Ferguson', 'Richard Marcinko', 'David', 'William J. Bennett',
#        'Tom Hegg', 'Alex Walsh', 'William Shatner', 'Margaret Mitchell',
#        'Dr. Seuss', 'Jackie Collins', 'L. Ron Hubbard', 'Fannie Flagg',
#        'Jamie Lee Curtis', 'Clement Moore', 'Tim LaHaye', 'Maria Shriver',
#        'John Updike', 'Brian Herbert', 'Seamus Heaney',
#        'Mary Higgins Clark', 'Rita Mae Brown', 'Caroline Kennedy',
#        'Mario Puzo', 'Joyce Reardon', 'James Patterson',
#        'Emma McLaughlin', 'Hannah Crafts', 'Clive Cussler',
#        'Oliver North', 'Newt Gingrich', 'Nora Roberts',
#        'W. E. B. Griffin', 'Susan Elizabeth Phillips', 'Sophie Kinsella',
#        'Ian Caldwell', 'Douglas Preston', 'Sidney Sheldon', 'Faye',
#        'Marcie Walsh', 'Terry Pratchett', 'W.E.B. Griffin',
#        'Anne McCaffrey', 'J. R. R. Tolkien', 'Dick Francis',
#        'Julia London', 'Michael Reaves', 'Amanda Goldberg',
#        'Iris Johansen', 'Mary Ann Shaffer', 'Glenn Beck with Kevin Balfe',
#        'Guillermo del Toro', 'Newt Gingrich, William R. Forstchen',
#        'Robert Jordan', 'Charlaine Harris', 'Tom Clancy',
#        'Anders Roslund', 'Michael Crichton', 'Janet Evanovich',
#        'Bethenny Frankel', 'Orson Scott Card', 'Glenn Beck',
#        'James Rollins', 'Catherine Coulter', 'Robert Kirkman',
#        'Robert B. Parker', 'George R. R. Martin', 'Jonathan Kellerman',
#        'Lucia Berlin', 'Vince Flynn', 'John Sandford', 'Joseph Fink',
#        'Brad Meltzer', 'Stuart Woods', 'Neal Stephenson',
#        'Elizabeth Peters', 'Greer Hendricks', 'Bill Clinton',
#        'Khaled Hosseini', 'Mark Greaney', 'Nelson DeMille', 'Jim Carrey',
#        'Lee Child'], dtype=object)

# %%
nyt_review.author_2.unique()
# Out:
# array(['James N. Hall', nan, 'James Norman Hall', 'J. H. Links',
#        'Willard Shepard', 'Nancy Freedman', 'Audrey Wurdemann',
#        'James Childers', 'George Johnston', 'Victor Leclerc',
#        'Joseph Hayes', 'Patrick Dennis', 'Eugene Burdick',
#        'Daphne du Maurier', 'Charles W. Bailey II', 'Harvey Wheeler',
#        'Mason Hoffenberg', 'John Clive', 'Ted Koppel',
#        'Other Top-ranking NATO Generals', 'Robert Moss',
#        'Dominique Lapierre', 'James Elward', 'written by Thomas Chastain',
#        'Arnaud de Borchgrave', 'James W. Kunetka', 'Peter Straub',
#        'Jerry Pournelle', 'Maureen Strange Foster', 'Steven L. Thompson',
#        'Robert B. Parker', 'Garfield Reeves-Stevens', 'Louise Erdrich',
#        'Tracy Hickman', 'Gentry Lee', 'Allan Ahlberg', 'John Weisman',
#        'Leigh Eddings', 'Kevin J. Anderson', 'Jerry B. Jenkins',
#        'Katrina Kenison', 'Dave Wolverton', 'Carol Higgins Clark',
#        'Sneaky Pie Brown', 'Andrew Gross', 'Nicola Kraus',
#        'Paul Kemprecos', 'Peter de Jonge', 'Joe Musser',
#        'William R. Forstchen', 'J. D. Robb', 'Greg Dinallo',
#        'Dustin Thomason', 'Lincoln Child', 'Bob Phillips',
#        'Jonathan Kellerman', 'Dirk Cussler', 'Howard Roughan',
#        'Michael Malone', 'Maxine Paetro', 'William E. Butterworth IV',
#        'Todd McCaffrey', 'Michael Ledwidge', 'Felix Francis',
#        'Alina Adams', 'Steve Perry', 'Ruthanna Khalighi Hopper',
#        'Gabrielle Charbonnet', 'Jack Du Brul', 'Roy Johansen',
#        'Annie Barrows', 'Jason Wright', 'Chuck Hogan', 'Richard DiLallo',
#        'Grant Blackwood', 'Albert S. Hanser', 'Brandon Sanderson',
#        'Justin Scott', 'Toni L. P. Kelner', 'Liza Marklund',
#        'Borge Hellstrom', 'Neil McMahon', 'Peter Telep', 'Marshall Karp',
#        'Graham Brown', 'Richard Preston', 'Mark Greaney', 'Dorien Kelly',
#        'Mark Sullivan', 'David Ellis', 'Eve Adamson', 'Stephen Baxter',
#        'Aaron Johnston', 'Thomas Perry', 'Harriet Parke',
#        'Rebecca Cantrell', 'Lee Goldberg', 'Jack Henderson',
#        'J.\u2009T. Ellison', 'Jay Bonansinga', 'Helen Brann',
#        'Emily Raymond', 'Gardner Dozois', 'Russell Blake',
#        'Jesse Kellerman', 'Alafair Burke', 'Peter De Jonge',
#        'Boyd Morrison', 'Phoef Sutton', 'J.T. Ellison', 'Kyle Mills',
#        'Ctein', 'Jeffrey Cranor', 'Tod Goldberg', 'Parnell Hall',
#        'Robin Burcell', 'William E. Butterworth', 'Candice Fox',
#        'Emily Raymond with Jill Dembowski',
#        'Frank Costantini, Emily Raymond', 'Richard Chizmar',
#        'Nicole Galland', 'Joan Hess', 'James O. Born', 'Owen King',
#        'Sarah Pekkanen', 'Daniel Kraus', 'James Patterson',
#        'Andrew Bourelle', 'Nancy Allen', 'Max DiLallo', 'Brendan DuBois',
#        'Peter Evanovich', 'Hunter Ripley Rawlings IV', 'Alex DeMille',
#        'Dana Vachon', 'Chris Tebbetts', 'J.D. Barker', 'Andrew Child',
#        'Shan Serafin'], dtype=object)

# %%
# if there's only one name in the author_1 column,
