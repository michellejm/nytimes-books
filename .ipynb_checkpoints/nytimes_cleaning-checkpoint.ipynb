# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Suppress the warning for this file
# ok, this is likely a bad idea, but there's going to be a lot of these
pd.options.mode.chained_assignment = None

# %%
nyt = pd.read_csv("nyt_full.tsv", sep = '\t')
nyt.head()
# Out:
#    year        week  rank  title_id                      title  \
# 0  1931  1931-10-12     1      6477       THE TEN COMMANDMENTS
# 1  1931  1931-10-12     2      1808           FINCHE'S FORTUNE
# 2  1931  1931-10-12     3      5304             THE GOOD EARTH
# 3  1931  1931-10-12     4      4038        SHADOWS ON THE ROCK
# 4  1931  1931-10-12     5      3946  SCARMOUCHE THE KING MAKER
#
#              author
# 0   Warwick Deeping
# 1  Mazo de la Roche
# 2     Pearl S. Buck
# 3      Willa Cather
# 4   Rafael Sabatini

# %%
nyt.author.nunique()
# Out:
# 2210

# %%
print(nyt.author)
# Out:
# 0                        Warwick Deeping
# 1                       Mazo de la Roche
# 2                          Pearl S. Buck
# 3                           Willa Cather
# 4                        Rafael Sabatini
#                       ...
# 60381                             Halsey
# 60382                       Brit Bennett
# 60383                        Delia Owens
# 60384                    Fredrik Backman
# 60385    Clive Cussler and Boyd Morrison
# Name: author, Length: 60386, dtype: object

# %%
# replace written & illustrated by 
nyt.author = nyt.author.replace("written and illustrated by ","", regex = True)

# %% [markdown]
# ## separate complicated entries

# %%
#if there is a preposition, there's complication
nyt.author = nyt.author.replace(" And "," and ", regex = True)
nyt['problem'] = nyt.author.str.contains(' and | with | by ', regex = True, case = False)
print("how many problem entries", nyt.problem.sum())
print(nyt.problem.sum()/len(nyt))

# new dataframe with just problems
nyt_review = nyt[nyt.problem == True]
print("how many unique problems", len(nyt_review.author.unique()))

#new dataframe without problems 
nyt_single = nyt[nyt.problem == False]
nyt_single.to_csv('nyt_single_authors.csv', index=False)
# Out:
# how many problem entries 2416
# 0.04000927367270559
# how many unique problems 189

# %% [raw]
# # editors
# #has_edited = nyt_review.author.str.contains('edited', regex = True, case = False)
# nyt_review['edited'] = nyt_review.author.str.contains('edited', regex = True, case = False)
# nyt_review.edited.sum()
#
# # new dataframe with just editors
# nyt_edited = nyt_review[nyt_review.edited == True]
# print(nyt_edited.author.unique())

# %%
# if there's an author with editor, remove editor, else treat editor as author 
nyt_review.author = nyt_review.author.replace(", edited by ",". Edited by ", regex = True)

#remove 'edited by ' and transfer rest of string to the 'author_alt' column
def resolve_editors(name):
    if 'dited ' in name:
        if name[:10] == 'edited by ':
            return name[10:]
        elif name[:10] != 'edited by ':
            substring = ('. Edited by ')
            return name.split(substring)[0]
    else: return name

nyt_review['author_alt'] = nyt_review.apply(lambda x: resolve_editors(x['author']), axis = 1)

# %%
print(nyt_review['author_alt'].unique()[:5])
# Out:
# ['Charles Nordhoff and James N. Hall' 'Gideon Wyck'
#  'Charles Nordloff and James Norman Hall'
#  'Dennis Wheatley and J. H. Links' 'Somerset Maugham']

# %%
def resolve_illustrators(name):
    substring = ('. Illustrated by ')
    return name.split(substring)[0]
    
nyt_review['author_alt'] = nyt_review.apply(lambda x: resolve_illustrators(x['author_alt']), axis = 1)
nyt_review.author_alt.unique()[5:25]
# Out:
# array(['Charles Nordhoff and James Norman Hall', 'Armin L. Robinson',
#        'Odell Shepard and Willard Shepard', '? by Isabel Bolton',
#        'Benedict Freedman and Nancy Freedman',
#        'Joseph Auslander and Audrey Wurdemann',
#        'James Street and James Childers',
#        'Charmian Clift and George Johnston',
#        'Harnett T. Kane and Victor Leclerc', 'Marrijane and Joseph Hayes',
#        'Dorothy Erskine and Patrick Dennis',
#        'William J. Lederer and Eugene Burdick',
#        'Arthur Quiller-Couch and Daphne du Maurier',
#        'Fletcher Knebel and Charles W. Bailey II',
#        'Eugene Burdick and Harvey Wheeler',
#        'Terry Southern and Mason Hoffenberg', 'Nicholas Meyer',
#        'J.D. Gilman and John Clive', 'Marvin Kalb and Ted Koppel',
#        'General Sir John Hackett and Other Top-ranking NATO Generals and Advisors'],
#       dtype=object)

# %%
#some custom cleaning
#typo in name
nyt_review.author_alt = nyt_review.author_alt.replace("Charles Nordloff","Charles Nordhoff", regex = True)
nyt_review.author_alt = nyt_review.author_alt.replace("William Shatner with Judith$","William Shatner with Judith Reeves-Stevens", regex = True)
nyt_review.author_alt = nyt_review.author_alt.replace("Constantini","Costantini", regex = True)
nyt_review.author_alt = nyt_review.author_alt.replace("J. T. Ellison","J.T. Ellison", regex = True)

# %%
def split_two_authors(name):
    substring1 = (' and ')
    substring2 = (' with ')
    if substring1 in name:
        first_author = name.split(substring1)[0]
        second_author = name.split(substring1)[1]
    elif substring2 in name:
        first_author = name.split(substring2)[0]
        second_author = name.split(substring2)[1]
    else:
        first_author = name
        second_author = np.nan
    return first_author, second_author

nyt_review[['author_1', 'author_2']] = nyt_review.apply(lambda x: split_two_authors(x['author_alt']), axis=1, result_type='expand')

# %%
nyt_review.author_1.unique()
# Out:
# array(['Charles Nordhoff', 'Gideon Wyck', 'Dennis Wheatley',
#        'Somerset Maugham', 'Armin L. Robinson', 'Odell Shepard',
#        '? by Isabel Bolton', 'Benedict Freedman', 'Joseph Auslander',
#        'James Street', 'Charmian Clift', 'Harnett T. Kane', 'Marrijane',
#        'Dorothy Erskine', 'William J. Lederer', 'Arthur Quiller-Couch',
#        'Fletcher Knebel', 'Eugene Burdick', 'Terry Southern',
#        'Nicholas Meyer', 'J.D. Gilman', 'Marvin Kalb',
#        'General Sir John Hackett', 'Arnaud de Borchgrave',
#        'Larry Collins', 'Helen Van Slyke', 'adapted by Joan D. Vinge',
#        'created by Bill Adler', 'Robert Moss', 'Whitley Strieber',
#        'Stephen King', 'Larry Niven', 'Patti Davis', '! by Terry Brooks',
#        'Walter J. Boyne', 'compiled by Mary S. Lovell',
#        'Raymond Chandler', 'Judith', 'Barry Lopez', 'Michael Dorris',
#        'Margaret Weis', 'Arthur C. Clarke', 'Janet', '? by Jimmy Buffett',
#        'adapted by Don Ferguson', 'Richard Marcinko', 'David',
#        'William J. Bennett', 'Tom Hegg', 'Alex Walsh',
#        'William Shatner with Judith', 'Margaret Mitchell', 'Dr. Seuss',
#        'William Shatner with Judith Reeves-Stevens',
#        '! by Jackie Collins', 'L. Ron Hubbard', '! by Fannie Flagg',
#        'Jamie Lee Curtis', 'Clement Moore', 'Tim LaHaye', 'Maria Shriver',
#        'John Updike', 'Brian Herbert', 'translated by Seamus Heaney',
#        'Mary Higgins Clark', 'Rita Mae Brown',
#        'selected by Caroline Kennedy',
#        'Mario Puzo. Completed by Carol Gino', 'Joyce Reardon',
#        'James Patterson', 'Emma McLaughlin', 'Hannah Crafts',
#        'Clive Cussler', 'Oliver North', 'Newt Gingrich', 'Nora Roberts',
#        '! by W. E. B. Griffin', '? by Susan Elizabeth Phillips',
#        '? by Sophie Kinsella', 'Ian Caldwell', 'Douglas Preston',
#        '? by Sidney Sheldon', 'Faye', 'Marcie Walsh',
#        '! by Terry Pratchett', 'W.E.B. Griffin', 'Anne McCaffrey',
#        'J. R. R. Tolkien', 'W. E. B. Griffin', 'Dick Francis',
#        'Julia London', 'Michael Reaves', 'Amanda Goldberg',
#        'Iris Johansen', 'Mary Ann Shaffer', 'Glenn Beck with Kevin Balfe',
#        'Guillermo del Toro', 'Newt Gingrich, William R. Forstchen',
#        'Robert Jordan', 'Charlaine Harris', 'Tom Clancy',
#        'Anders Roslund', 'Michael Crichton', 'Janet Evanovich',
#        'Bethenny Frankel', 'Terry Pratchett', 'Orson Scott Card',
#        'Glenn Beck', 'James Rollins', 'Catherine Coulter',
#        'Robert Kirkman', 'Robert B. Parker', 'George R. R. Martin',
#        'Jonathan Kellerman', 'Lucia Berlin', 'Vince Flynn',
#        'John Sandford', 'Joseph Fink', 'Brad Meltzer', 'Stuart Woods',
#        'Neal Stephenson', 'Elizabeth Peters', 'Greer Hendricks',
#        'Bill Clinton', 'Khaled Hosseini', 'Mark Greaney',
#        'Nelson DeMille', 'Jim Carrey', 'Lee Child'], dtype=object)

# %%
#replace lost characters
nyt_review.author_1 = nyt_review.author_1.replace("! by ","", regex = True)
nyt_review.author_1 = nyt_review.author_1.replace(r"\? by ","", regex = True)

#replace other ways of saying editor
nyt_review.author_1 = nyt_review.author_1.replace("selected by ","", regex = True)
nyt_review.author_1 = nyt_review.author_1.replace("compiled by ","", regex = True)
nyt_review.author_1 = nyt_review.author_1.replace("translated by ","", regex = True)
nyt_review.author_1 = nyt_review.author_1.replace("adapted by ","", regex = True)
nyt_review.author_1 = nyt_review.author_1.replace("created by ","", regex = True)
#
nyt_review.author_1 = nyt_review.author_1.replace(". Completed by Carol Gino","", regex = True)
nyt_review.author_1 = nyt_review.author_1.replace("William Shatner with Judith Reeves-Stevens","William Shatner", regex = True)
nyt_review.author_1 = nyt_review.author_1.replace("William Shatner with Judith","William Shatner", regex = True)

# %%
nyt_review.author_1.unique()
# Out:
# array(['Charles Nordhoff', 'Gideon Wyck', 'Dennis Wheatley',
#        'Somerset Maugham', 'Armin L. Robinson', 'Odell Shepard',
#        'Isabel Bolton', 'Benedict Freedman', 'Joseph Auslander',
#        'James Street', 'Charmian Clift', 'Harnett T. Kane', 'Marrijane',
#        'Dorothy Erskine', 'William J. Lederer', 'Arthur Quiller-Couch',
#        'Fletcher Knebel', 'Eugene Burdick', 'Terry Southern',
#        'Nicholas Meyer', 'J.D. Gilman', 'Marvin Kalb',
#        'General Sir John Hackett', 'Arnaud de Borchgrave',
#        'Larry Collins', 'Helen Van Slyke', 'Joan D. Vinge', 'Bill Adler',
#        'Robert Moss', 'Whitley Strieber', 'Stephen King', 'Larry Niven',
#        'Patti Davis', 'Terry Brooks', 'Walter J. Boyne', 'Mary S. Lovell',
#        'Raymond Chandler', 'Judith', 'Barry Lopez', 'Michael Dorris',
#        'Margaret Weis', 'Arthur C. Clarke', 'Janet', 'Jimmy Buffett',
#        'Don Ferguson', 'Richard Marcinko', 'David', 'William J. Bennett',
#        'Tom Hegg', 'Alex Walsh', 'William Shatner', 'Margaret Mitchell',
#        'Dr. Seuss', 'Jackie Collins', 'L. Ron Hubbard', 'Fannie Flagg',
#        'Jamie Lee Curtis', 'Clement Moore', 'Tim LaHaye', 'Maria Shriver',
#        'John Updike', 'Brian Herbert', 'Seamus Heaney',
#        'Mary Higgins Clark', 'Rita Mae Brown', 'Caroline Kennedy',
#        'Mario Puzo', 'Joyce Reardon', 'James Patterson',
#        'Emma McLaughlin', 'Hannah Crafts', 'Clive Cussler',
#        'Oliver North', 'Newt Gingrich', 'Nora Roberts',
#        'W. E. B. Griffin', 'Susan Elizabeth Phillips', 'Sophie Kinsella',
#        'Ian Caldwell', 'Douglas Preston', 'Sidney Sheldon', 'Faye',
#        'Marcie Walsh', 'Terry Pratchett', 'W.E.B. Griffin',
#        'Anne McCaffrey', 'J. R. R. Tolkien', 'Dick Francis',
#        'Julia London', 'Michael Reaves', 'Amanda Goldberg',
#        'Iris Johansen', 'Mary Ann Shaffer', 'Glenn Beck with Kevin Balfe',
#        'Guillermo del Toro', 'Newt Gingrich, William R. Forstchen',
#        'Robert Jordan', 'Charlaine Harris', 'Tom Clancy',
#        'Anders Roslund', 'Michael Crichton', 'Janet Evanovich',
#        'Bethenny Frankel', 'Orson Scott Card', 'Glenn Beck',
#        'James Rollins', 'Catherine Coulter', 'Robert Kirkman',
#        'Robert B. Parker', 'George R. R. Martin', 'Jonathan Kellerman',
#        'Lucia Berlin', 'Vince Flynn', 'John Sandford', 'Joseph Fink',
#        'Brad Meltzer', 'Stuart Woods', 'Neal Stephenson',
#        'Elizabeth Peters', 'Greer Hendricks', 'Bill Clinton',
#        'Khaled Hosseini', 'Mark Greaney', 'Nelson DeMille', 'Jim Carrey',
#        'Lee Child'], dtype=object)

# %%
nyt_review.author_2.unique()[:10]
# Out:
# array(['James N. Hall', nan, 'James Norman Hall', 'J. H. Links',
#        'Willard Shepard', 'Nancy Freedman', 'Audrey Wurdemann',
#        'James Childers', 'George Johnston', 'Victor Leclerc'],
#       dtype=object)

# %%
# if there's only one name in the author_1 column, return that row
nyt_review[~nyt_review.author_1.str.contains(' ')]
# Out:
#        year        week  rank  title_id                        title  \
# 13772  1957  1957-02-24    15       792                   BON VOYAGE
# 36330  1990  1990-09-16    10      3609              PRIME DIRECTIVE
# 36346  1990  1990-09-23    11      3609              PRIME DIRECTIVE
# 36361  1990  1990-09-30    11      3609              PRIME DIRECTIVE
# 36378  1990  1990-10-07    13      3609              PRIME DIRECTIVE
# 36395  1990  1990-10-14    15      3609              PRIME DIRECTIVE
# 37334  1991  1991-12-22     5      5511  THE JOLLY CHRISTMAS POSTMAN
# 37350  1991  1991-12-29     6      5511  THE JOLLY CHRISTMAS POSTMAN
# 37367  1992  1992-01-05     8      5511  THE JOLLY CHRISTMAS POSTMAN
# 37383  1992  1992-01-12     9      5511  THE JOLLY CHRISTMAS POSTMAN
# 37399  1992  1992-01-19    10      5511  THE JOLLY CHRISTMAS POSTMAN
# 39599  1994  1994-10-30    12      4288         STAR TREK FEDERATION
# 39615  1994  1994-11-06    13      4288         STAR TREK FEDERATION
# 39647  1994  1994-11-20    15      4288         STAR TREK FEDERATION
# 40233  1995  1995-08-20    11       649       BELGARATH THE SORCERER
# 40249  1995  1995-08-27    12       649       BELGARATH THE SORCERER
# 40261  1995  1995-09-03     9       649       BELGARATH THE SORCERER
# 40280  1995  1995-09-10    13       649       BELGARATH THE SORCERER
# 41986  1997  1997-11-02    12      3553        POLGARA THE SORCERESS
# 42000  1997  1997-11-09    11      3553        POLGARA THE SORCERESS
# 42018  1997  1997-11-16    14      3553        POLGARA THE SORCERESS
# 47525  2004  2004-10-24    12      1510              DOUBLE HOMICIDE
#
#                                    author problem  \
# 13772          Marrijane and Joseph Hayes    True
# 36330  Judith and Garfield Reeves-Stevens    True
# 36346  Judith and Garfield Reeves-Stevens    True
# 36361  Judith and Garfield Reeves-Stevens    True
# 36378  Judith and Garfield Reeves-Stevens    True
# 36395  Judith and Garfield Reeves-Stevens    True
# 37334             Janet and Allan Ahlberg    True
# 37350             Janet and Allan Ahlberg    True
# 37367             Janet and Allan Ahlberg    True
# 37383             Janet and Allan Ahlberg    True
# 37399             Janet and Allan Ahlberg    True
# 39599  Judith and Garfield Reeves-Stevens    True
# 39615  Judith and Garfield Reeves-Stevens    True
# 39647  Judith and Garfield Reeves-Stevens    True
# 40233             David and Leigh Eddings    True
# 40249             David and Leigh Eddings    True
# 40261             David and Leigh Eddings    True
# 40280             David and Leigh Eddings    True
# 41986             David and Leigh Eddings    True
# 42000             David and Leigh Eddings    True
# 42018             David and Leigh Eddings    True
# 47525         Faye and Jonathan Kellerman    True
#
#                                author_alt   author_1                 author_2
# 13772          Marrijane and Joseph Hayes  Marrijane             Joseph Hayes
# 36330  Judith and Garfield Reeves-Stevens     Judith  Garfield Reeves-Stevens
# 36346  Judith and Garfield Reeves-Stevens     Judith  Garfield Reeves-Stevens
# 36361  Judith and Garfield Reeves-Stevens     Judith  Garfield Reeves-Stevens
# 36378  Judith and Garfield Reeves-Stevens     Judith  Garfield Reeves-Stevens
# 36395  Judith and Garfield Reeves-Stevens     Judith  Garfield Reeves-Stevens
# 37334             Janet and Allan Ahlberg      Janet            Allan Ahlberg
# 37350             Janet and Allan Ahlberg      Janet            Allan Ahlberg
# 37367             Janet and Allan Ahlberg      Janet            Allan Ahlberg
# 37383             Janet and Allan Ahlberg      Janet            Allan Ahlberg
# 37399             Janet and Allan Ahlberg      Janet            Allan Ahlberg
# 39599  Judith and Garfield Reeves-Stevens     Judith  Garfield Reeves-Stevens
# 39615  Judith and Garfield Reeves-Stevens     Judith  Garfield Reeves-Stevens
# 39647  Judith and Garfield Reeves-Stevens     Judith  Garfield Reeves-Stevens
# 40233             David and Leigh Eddings      David            Leigh Eddings
# 40249             David and Leigh Eddings      David            Leigh Eddings
# 40261             David and Leigh Eddings      David            Leigh Eddings
# 40280             David and Leigh Eddings      David            Leigh Eddings
# 41986             David and Leigh Eddings      David            Leigh Eddings
# 42000             David and Leigh Eddings      David            Leigh Eddings
# 42018             David and Leigh Eddings      David            Leigh Eddings
# 47525         Faye and Jonathan Kellerman       Faye       Jonathan Kellerman

# %%
#individually reunite the single names with their last names
nyt_review.author_1 = nyt_review.author_1.replace("Judith","Judith Reeves-Stevens", regex = True)
nyt_review.author_1 = nyt_review.author_1.replace("Janet","Janet Ahlberg", regex = True)
nyt_review.author_1 = nyt_review.author_1.replace("David","David Eddings", regex = True)
nyt_review.author_1 = nyt_review.author_1.replace("Faye","Faye Kellerman", regex = True)
nyt_review.author_1 = nyt_review.author_1.replace("Marrijane","Marrijane Hayes", regex = True)

nyt_review.author_1.unique()[:5]
# Out:
# array(['Charles Nordhoff', 'Gideon Wyck', 'Dennis Wheatley',
#        'Somerset Maugham', 'Armin L. Robinson'], dtype=object)

# %%
nyt_single = pd.read_csv("nyt_single_author_demographics.csv")

nyt_single.rename(columns = {'Unnamed: 0':'author'}, inplace=True)
nyt_single.tail()
# Out:
#             author birth death             race_eth           education  \
# 2015  Lana Del Rey  1985   N/A                White                None
# 2016     Matt Haig  1975   N/A                White   Bachelor's Degree
# 2017   Rumaan Alam  1977   N/A   Pakistani-American   Bachelor’s Degree
# 2018    Susie Yang  1983   N/A       Asian American                 MFA
# 2019        Halsey  1994   N/A                White   Bachelor's Degree
#
#                          institution
# 2015                            None
# 2016              University of Kent
# 2017          University of Michigan
# 2018        University of California
# 2019   Rhode Island School of Design

# %% [markdown]
# ![join](IMG_0722.jpg)

# %%
# return all of the names in nyt_review.author_1 that are NOT in nyt_single.author
# going to use an outer merge

nyt_review_not_in_single = nyt_single.merge(nyt_review, how='outer', left_on = 'author', right_on = 'author_1', indicator = True)
nyt_review_not_in_single =nyt_review_not_in_single[nyt_review_not_in_single._merge == 'right_only']
print(len(nyt_review_not_in_single.author_1.unique()))
nyt_review_not_in_single.head()
# Out:
# 61
#     author_x birth death race_eth education institution    year        week  \
# 55       NaN   NaN   NaN      NaN       NaN         NaN  1995.0  1995-12-31
# 92       NaN   NaN   NaN      NaN       NaN         NaN  2008.0  2008-03-02
# 99       NaN   NaN   NaN      NaN       NaN         NaN  2011.0  2011-01-23
# 100      NaN   NaN   NaN      NaN       NaN         NaN  2011.0  2011-01-30
# 101      NaN   NaN   NaN      NaN       NaN         NaN  2011.0  2011-02-06
#
#      rank  title_id          title  \
# 55   14.0    6336.0  THE SMALL ONE
# 92   15.0     974.0   CELEBUTANTES
# 99    9.0    6836.0  THREE SECONDS
# 100   8.0    6836.0  THREE SECONDS
# 101  15.0    6836.0  THREE SECONDS
#
#                                          author_y problem  \
# 55          Alex Walsh. Illustrated by Jesse Clay    True
# 92   Amanda Goldberg and Ruthanna Khalighi Hopper    True
# 99             Anders Roslund and Borge Hellstrom    True
# 100            Anders Roslund and Borge Hellstrom    True
# 101            Anders Roslund and Borge Hellstrom    True
#
#                                        author_alt         author_1  \
# 55                                     Alex Walsh       Alex Walsh
# 92   Amanda Goldberg and Ruthanna Khalighi Hopper  Amanda Goldberg
# 99             Anders Roslund and Borge Hellstrom   Anders Roslund
# 100            Anders Roslund and Borge Hellstrom   Anders Roslund
# 101            Anders Roslund and Borge Hellstrom   Anders Roslund
#
#                      author_2      _merge
# 55                        NaN  right_only
# 92   Ruthanna Khalighi Hopper  right_only
# 99            Borge Hellstrom  right_only
# 100           Borge Hellstrom  right_only
# 101           Borge Hellstrom  right_only

# %%
#write to csv
nyt_review_not_in_single.to_csv('nyt_reviewed_authors.csv', index=False)

# %% [markdown]
# ## Combine the single and reviewed author demographics

# %%
demo_single = pd.read_csv("nyt_single_author_demographics.csv")
demo_single.rename(columns = {"Unnamed: 0":"author"}, inplace=True)

demo_review = pd.read_csv("nyt_reviewed_author_demographics.csv")
demo_review.drop("Unnamed: 0", axis = 1, inplace=True)


print(demo_single.head())
print(demo_review.head())
# Out:
#              author birth  death    race_eth           education  \
# 0   Warwick Deeping  1877   1950     English                None
# 1  Mazo de la Roche  1879   1961    Canadian                None
# 2     Pearl S. Buck  1892   1973   Caucasian               Ph.D.
# 3      Willa Cather  1873   1947    American   Bachelor's Degree
# 4   Rafael Sabatini  1875   1950     Italian                None
#
#                        institution
# 0                             None
# 1                             None
# 2               Cornell University
# 3   University of Nebraska-Lincoln
# 4                             None
#                  author birth  death           race_eth           education  \
# 0            Alex Walsh   NaN   None               None                None
# 1       Amanda Goldberg  1970    N/A           American   Bachelor's Degree
# 2        Anders Roslund  1965    N/A            Swedish   Bachelor's Degree
# 3     Armin L. Robinson  1953    N/A   African American   Bachelor's Degree
# 4  Arnaud de Borchgrave  1926   2019            Belgian   Bachelor's Degree
#
#                          institution
# 0                               None
# 1                 Harvard University
# 2           University of Gothenburg
# 3           University of California
# 4   Université catholique de Louvain

# %%
demographics = pd.concat([demo_single, demo_review])
print(len(demographics))
len(demographics.author.unique())
# Out:
# 2081
# 2081

# %%
#should've fixed this earlier
demographics = demographics[demographics.author != "various authors"]
len(demographics.author.unique())
# Out:
# 2080

# %% [markdown]
# ## Clean the birthplace information

# %%
birth_single = pd.read_csv("nyt_single_author_birthplace.csv")
birth_single.rename(columns = {"Unnamed: 0":"author"}, inplace=True)

birth_review = pd.read_csv("nyt_reviewed_author_birthplace.csv")
birth_review.drop("Unnamed: 0", axis = 1, inplace=True)


print(birth_single.head())
print(birth_review.head())
# Out:
#              author                        birthplace
# 0   Warwick Deeping           Ramsgate, Kent, England
# 1  Mazo de la Roche        Newmarket, Ontario, Canada
# 2     Pearl S. Buck                Hillsboro, WV, USA
# 3      Willa Cather  Back Creek Valley, Virginia, USA
# 4   Rafael Sabatini              Fermo, Marche, Italy
#                  author            birthplace
# 0            Alex Walsh                   NaN
# 1       Amanda Goldberg  Los Angeles, CA, USA
# 2        Anders Roslund     Stockholm, Sweden
# 3     Armin L. Robinson                   NaN
# 4  Arnaud de Borchgrave     Brussels, Belgium

# %%
birth = pd.concat([birth_single, birth_review])
print(len(birth))
len(birth.author.unique())
# Out:
# 2025
# 2025

# %%
#should've fixed this earlier
birth = birth[birth.author != "various authors"]

# %%
birth['temp'] = birth.birthplace.str.split(',')
birth.head()
# Out:
#              author                        birthplace  \
# 0   Warwick Deeping           Ramsgate, Kent, England
# 1  Mazo de la Roche        Newmarket, Ontario, Canada
# 2     Pearl S. Buck                Hillsboro, WV, USA
# 3      Willa Cather  Back Creek Valley, Virginia, USA
# 4   Rafael Sabatini              Fermo, Marche, Italy
#
#                                    temp
# 0           [Ramsgate,  Kent,  England]
# 1        [Newmarket,  Ontario,  Canada]
# 2                [Hillsboro,  WV,  USA]
# 3  [Back Creek Valley,  Virginia,  USA]
# 4              [Fermo,  Marche,  Italy]

# %%
#birthplace['list_len'] = birthplace.temp.apply(len)
print(birth.temp.iloc[0])
print(birth.temp.iloc[0][-1])
type(birth.temp.iloc[0])
# Out:
# ['Ramsgate', ' Kent', ' England']
#  England
# list

# %%
def get_country(temp):
    if isinstance(temp, list) and temp:
        return temp[-1] 
    else: None


birth['country'] = birth.temp.apply(get_country)

# %%
birth.country.unique()
# Out:
# array([' England', ' Canada', ' USA', ' Italy', ' France', ' UK',
#        ' Ireland', ' Austria', ' Scotland', None, ' New Zealand',
#        ' Germany', ' Denmark', ' None', ' Austria-Hungary',
#        ' South Africa', ' Czech Republic', ' Switzerland',
#        ' Austria-Hungary (now Czech Republic)', ' Slovenia',
#        ' British Guiana', ' Spain', ' Hungary', ' Norway', ' Finland',
#        ' Iceland', ' China', ' Egypt', ' India', ' Poland', ' Russia',
#        ' Reino Unido', ' Australia', ' Ukraine', ' Iceland.', ' Romania',
#        ' Algeria', ' Northern Ireland', ' Sweden', ' Netherlands',
#        ' Belgium', ' USA.', ' Greece', ' Wales', ' Japan',
#        ' Russian Empire (now Ukraïne)', ' Indonesia', ' Israel',
#        ' United Kingdom', ' Brazil', ' Poland)', ' South Korea',
#        ' Turkey', ' Colombia', ' Iran', ' Kenya', ' Zambia', ' Peru',
#        ' Vietnam', ' Panama', ' Trinidad and Tobago', ' Mexico',
#        ' Sri Lanka', ' Zimbabwe', ' Haiti', ' Lebanon', ' Pakistan',
#        ' Afghanistan', ' Dominican Republic', ' Serbia', ' England.',
#        ' Ghana', ' Cyprus', ' Jamaica', ' Malaysia', ' Nigeria'],
#       dtype=object)

# %%
birth.country = birth.country.replace(r" Poland\)", "Poland", regex = True)
birth.country = birth.country.replace(r"Austria-Hungary \(now Czech Republic\)", "Austria-Hungary", regex = True)
birth.country = birth.country.replace(r"Russian Empire \(now Ukraïne\)", "Ukraine", regex = True)
birth.country = birth.country.replace(r"Reino Unido|UK", "United Kingdom", regex = True)

birth.country = birth.country.replace(r"\.", "", regex = True)

birth.country = birth.country.replace(r"^\s+", "", regex = True)

# %%
birth.country.unique()
# Out:
# array(['England', 'Canada', 'USA', 'Italy', 'France', 'United Kingdom',
#        'Ireland', 'Austria', 'Scotland', None, 'New Zealand', 'Germany',
#        'Denmark', 'None', 'Austria-Hungary', 'South Africa',
#        'Czech Republic', 'Switzerland', 'Slovenia', 'British Guiana',
#        'Spain', 'Hungary', 'Norway', 'Finland', 'Iceland', 'China',
#        'Egypt', 'India', 'Poland', 'Russia', 'Australia', 'Ukraine',
#        'Romania', 'Algeria', 'Northern Ireland', 'Sweden', 'Netherlands',
#        'Belgium', 'Greece', 'Wales', 'Japan', 'Indonesia', 'Israel',
#        'Brazil', 'South Korea', 'Turkey', 'Colombia', 'Iran', 'Kenya',
#        'Zambia', 'Peru', 'Vietnam', 'Panama', 'Trinidad and Tobago',
#        'Mexico', 'Sri Lanka', 'Zimbabwe', 'Haiti', 'Lebanon', 'Pakistan',
#        'Afghanistan', 'Dominican Republic', 'Serbia', 'Ghana', 'Cyprus',
#        'Jamaica', 'Malaysia', 'Nigeria'], dtype=object)

# %%
def get_state(temp):
    if isinstance(temp, list) and temp:
        if temp[-1] == " USA":
            return temp[-2] 
    else: None


birth['state'] = birth.temp.apply(get_state)
birth.state.unique()
# Out:
# array([None, ' WV', ' Virginia', ' MI', ' CT', ' IL', ' IN', ' CO', ' PA',
#        ' NY', ' SC', ' VT', ' Ohio', ' MS', ' VA', ' Massachusetts',
#        ' MN', ' OH', ' D.C.', ' ME', ' IA', ' NJ', ' WY', ' MD', ' MA',
#        ' KS', ' GA', ' CA', ' WI', ' NC', ' KY', ' OR', ' DE', ' MO',
#        ' MT', ' AL', ' Nebraska', ' LA', ' ID', ' Mississippi', ' TN',
#        ' WA', ' NH', ' New Jersey', ' Texas', ' ND', ' Kentucky', ' UT',
#        ' AR', ' TX', ' RI', ' NV', '  New York', ' South Carolina', ' OK',
#        ' Colorado', ' Arkansas', 'Maine', ' FL', ' NM', ' NE', ' AZ',
#        ' Kansas', ' New York', ' HI', ' Oklahoma', ' Maryland', ' Iowa',
#        ' Oregon', 'Pennsylvania', ' California', ' Pennsylvania',
#        ' Connecticut', 'Nebraska', 'Connecticut', 'Alabama', ' Arizona',
#        ' Alabama', 'Massachusetts', 'Illinois', 'New Jersey', ' AK',
#        'Minnesota', 'North Carolina', 'California', ' None', 'Montana'],
#       dtype=object)

# %%
birth.state = birth.state.replace(r"^\s+", "", regex = True)
birth.state = birth.state.replace(r"Virginia", "VA", regex = True)
birth.state = birth.state.replace(r"Massachusetts", "MA", regex = True)
birth.state = birth.state.replace(r"Nebraska|Omaha", "NE", regex = True)
birth.state = birth.state.replace(r"Mississippi", "MS", regex = True)
birth.state = birth.state.replace(r"New Jersey", "NJ", regex = True)
birth.state = birth.state.replace(r"Arkansas", "AK", regex = True)
birth.state = birth.state.replace(r"New York", "NY", regex = True)
#birth.state = birth.state.replace(r"New York|Brooklyn|New York City|Queens", "NY", regex = True)
birth.state = birth.state.replace(r"Texas", "TX", regex = True)
birth.state = birth.state.replace(r"Kentucky", "KY", regex = True)
birth.state = birth.state.replace(r"South Carolina", "SC", regex = True)
birth.state = birth.state.replace(r"Colorado", "CO", regex = True)
birth.state = birth.state.replace(r"Kansas", "KS", regex = True)
birth.state = birth.state.replace(r"Oklahoma", "OK", regex = True)
birth.state = birth.state.replace(r"Maryland", "MD", regex = True)
birth.state = birth.state.replace(r"Iowa", "IA", regex = True)
birth.state = birth.state.replace(r"Oregon", "OR", regex = True)
birth.state = birth.state.replace(r"California", "CA", regex = True)
birth.state = birth.state.replace(r"Pennsylvania", "PA", regex = True)
birth.state = birth.state.replace(r"Connecticut", "CT", regex = True)
birth.state = birth.state.replace(r"Alabama", "AL", regex = True)
birth.state = birth.state.replace(r"Ohio", "OH", regex = True)
birth.state = birth.state.replace(r"Arizona", "AZ", regex = True)
birth.state = birth.state.replace(r"Illinois", "IL", regex = True)
birth.state = birth.state.replace(r"Maine", "ME", regex = True)
birth.state = birth.state.replace(r"Minnesota", "MN", regex = True)
birth.state = birth.state.replace(r"North Carolina", "NC", regex = True)
birth.state = birth.state.replace(r"Montana", "MT", regex = True)
birth.state.unique()
# Out:
# array([None, 'WV', 'VA', 'MI', 'CT', 'IL', 'IN', 'CO', 'PA', 'NY', 'SC',
#        'VT', 'OH', 'MS', 'MA', 'MN', 'D.C.', 'ME', 'IA', 'NJ', 'WY', 'MD',
#        'KS', 'GA', 'CA', 'WI', 'NC', 'KY', 'OR', 'DE', 'MO', 'MT', 'AL',
#        'NE', 'LA', 'ID', 'TN', 'WA', 'NH', 'TX', 'ND', 'UT', 'AR', 'RI',
#        'NV', 'OK', 'AK', 'FL', 'NM', 'AZ', 'HI', 'None'], dtype=object)

# %%
def get_city(temp):
    if isinstance(temp, list) and temp:
        return temp[0] 
    else: None


birth['city'] = birth.temp.apply(get_city)

# %%
print(birth.head())
print(demographics.head())
# Out:
#              author                        birthplace  \
# 0   Warwick Deeping           Ramsgate, Kent, England
# 1  Mazo de la Roche        Newmarket, Ontario, Canada
# 2     Pearl S. Buck                Hillsboro, WV, USA
# 3      Willa Cather  Back Creek Valley, Virginia, USA
# 4   Rafael Sabatini              Fermo, Marche, Italy
#
#                                    temp  country state               city
# 0           [Ramsgate,  Kent,  England]  England  None           Ramsgate
# 1        [Newmarket,  Ontario,  Canada]   Canada  None          Newmarket
# 2                [Hillsboro,  WV,  USA]      USA    WV          Hillsboro
# 3  [Back Creek Valley,  Virginia,  USA]      USA    VA  Back Creek Valley
# 4              [Fermo,  Marche,  Italy]    Italy  None              Fermo
#              author birth  death    race_eth           education  \
# 0   Warwick Deeping  1877   1950     English                None
# 1  Mazo de la Roche  1879   1961    Canadian                None
# 2     Pearl S. Buck  1892   1973   Caucasian               Ph.D.
# 3      Willa Cather  1873   1947    American   Bachelor's Degree
# 4   Rafael Sabatini  1875   1950     Italian                None
#
#                        institution
# 0                             None
# 1                             None
# 2               Cornell University
# 3   University of Nebraska-Lincoln
# 4                             None

# %% [markdown]
# ## Combine

# %%
auth_demo_birth = demographics.merge(birth, how='left', left_on = "author", right_on = "author", indicator = True)

# %%
auth_demo_birth = auth_demo_birth.replace(r"^\s+", "", regex = True)

# %%
auth_demo_birth[auth_demo_birth._merge !="both"]
# Out:
#                                    author                birth death  \
# 2024                 Arthur Quiller-Couch                 1863  1944
# 2025                          Barry Lopez                 1945   N/A
# 2026                    Benedict Freedman                 1904  1987
# 2027                     Bethenny Frankel                 1970   N/A
# 2028                           Bill Adler                 1942   N/A
# 2029                         Bill Clinton                 1946   N/A
# 2030                        Brian Herbert                 1947   N/A
# 2031                     Caroline Kennedy                 1957   N/A
# 2032                     Charles Nordhoff                 1887  1947
# 2033                       Charmian Clift                 1923  1969
# 2034                        Clement Moore                 1779  1863
# 2035                      Dennis Wheatley                 1897  1977
# 2036                         Don Ferguson                  NaN   N/A
# 2037                      Dorothy Erskine                 1892  1979
# 2038                      Emma McLaughlin                 1973   N/A
# 2039             General Sir John Hackett                 1910  1997
# 2040                          Gideon Wyck                 1982   N/A
# 2041          Glenn Beck with Kevin Balfe                 1964   N/A
# 2042                      Greer Hendricks                  NaN   N/A
# 2043                   Guillermo del Toro                 1964   N/A
# 2044                        Hannah Crafts                  NaN  None
# 2045                        Isabel Bolton                 1893  1975
# 2046                     J. R. R. Tolkien                 1892  1973
# 2047                          J.D. Gilman                 1960   N/A
# 2048                     Jamie Lee Curtis                 1958   N/A
# 2049                        Janet Ahlberg                 1944  1994
# 2050              Janet Ahlberg Evanovich                  NaN   N/A
# 2051                           Jim Carrey                 1962   N/A
# 2052                        Joan D. Vinge                 1943   N/A
# 2053                     Joseph Auslander                 1897  1965
# 2054                        Joyce Reardon                  NaN   N/A
# 2055                Judith Reeves-Stevens                 1950   N/A
# 2056                         Julia London                 1969   N/A
# 2057                          Larry Niven                 1938   N/A
# 2058                         Lucia Berlin                 1936  2004
# 2059                         Marcie Walsh                  NaN   N/A
# 2060                        Margaret Weis                 1948   N/A
# 2061                        Maria Shriver                 1955   N/A
# 2062                      Marrijane Hayes                 1945   N/A
# 2063                          Marvin Kalb                 1933   N/A
# 2064                     Mary Ann Shaffer                 1943  2008
# 2065                       Mary S. Lovell                 1939   N/A
# 2066                       Michael Dorris                 1945  1997
# 2067                        Newt Gingrich                 1943   N/A
# 2068  Newt Gingrich, William R. Forstchen  Newt Gingrich: 1943   N/A
# 2069                        Odell Shepard                 1884  1967
# 2070                         Oliver North                 1943   N/A
# 2071                          Patti Davis                 1943   N/A
# 2072                     Richard Marcinko                 1939   N/A
# 2073                        Seamus Heaney                 1939  2013
# 2074                       Terry Southern                 1924  1995
# 2075                           Tim LaHaye                 1926  2016
# 2076                      Walter J. Boyne                 1929  2020
# 2077                   William J. Bennett                 1943   N/A
# 2078                   William J. Lederer                 1912  2009
# 2079                      William Shatner                 1931   N/A
#
#               race_eth          education  \
# 2024           British               None
# 2025         Caucasian  Bachelor's Degree
# 2026             White  Bachelor's Degree
# 2027         Caucasian  Bachelor's Degree
# 2028             White  Bachelor's Degree
# 2029         Caucasian  Bachelor's Degree
# 2030         Caucasian  Bachelor's Degree
# 2031         Caucasian        J.D. Degree
# 2032             White               None
# 2033        Australian  Bachelor's Degree
# 2034             White               None
# 2035           British               None
# 2036              None               None
# 2037             White  Bachelor's Degree
# 2038         Caucasian  Bachelor's Degree
# 2039     White British    Master's Degree
# 2040              None  Bachelor's Degree
# 2041             White  Bachelor's Degree
# 2042              None               None
# 2043           Mexican               None
# 2044  African American               None
# 2045             White               None
# 2046           English  Bachelor's Degree
# 2047          American  Bachelor's Degree
# 2048         Caucasian  Bachelor's Degree
# 2049           British  Bachelor's Degree
# 2050          American               None
# 2051          Canadian               None
# 2052         Caucasian  Bachelor's Degree
# 2053            Jewish    Master's Degree
# 2054             White               None
# 2055         Caucasian  Bachelor's Degree
# 2056              None  Bachelor's Degree
# 2057         Caucasian  Bachelor's Degree
# 2058         Caucasian  Bachelor's Degree
# 2059              None               None
# 2060         Caucasian  Bachelor's Degree
# 2061         Caucasian  Bachelor's Degree
# 2062          American  Bachelor's Degree
# 2063         Caucasian          Doctorate
# 2064             White  Bachelor's Degree
# 2065           British  Bachelor's Degree
# 2066   Native American    Master's Degree
# 2067         Caucasian              Ph.D.
# 2068             White              Ph.D.
# 2069          American              Ph.D.
# 2070          American  Bachelor's Degree
# 2071         Caucasian  Bachelor's Degree
# 2072             White  Bachelor's Degree
# 2073             Irish  Bachelor's Degree
# 2074          American  Bachelor's Degree
# 2075             White  Bachelor's Degree
# 2076         Caucasian  Bachelor's Degree
# 2077          American          Doctorate
# 2078         Caucasian  Bachelor's Degree
# 2079          Canadian               None
#
#                                           institution birthplace temp country  \
# 2024                                             None        NaN  NaN     NaN
# 2025                             University of Oregon        NaN  NaN     NaN
# 2026                         University of California        NaN  NaN     NaN
# 2027                              New York University        NaN  NaN     NaN
# 2028                         City College of New York        NaN  NaN     NaN
# 2029                            Georgetown University        NaN  NaN     NaN
# 2030                      California State University        NaN  NaN     NaN
# 2031                              Columbia University        NaN  NaN     NaN
# 2032                                             None        NaN  NaN     NaN
# 2033                             University of Sydney        NaN  NaN     NaN
# 2034                                             None        NaN  NaN     NaN
# 2035                                             None        NaN  NaN     NaN
# 2036                                             None        NaN  NaN     NaN
# 2037                         University of California        NaN  NaN     NaN
# 2038                                  Barnard College        NaN  NaN     NaN
# 2039                                Oxford University        NaN  NaN     NaN
# 2040                          University of Minnesota        NaN  NaN     NaN
# 2041                      Washington State University        NaN  NaN     NaN
# 2042                                             None        NaN  NaN     NaN
# 2043                                             None        NaN  NaN     NaN
# 2044                                             None        NaN  NaN     NaN
# 2045                                             None        NaN  NaN     NaN
# 2046                                   Exeter College        NaN  NaN     NaN
# 2047                            University of Chicago        NaN  NaN     NaN
# 2048                               Chapman University        NaN  NaN     NaN
# 2049                            University of Reading        NaN  NaN     NaN
# 2050                                             None        NaN  NaN     NaN
# 2051                                             None        NaN  NaN     NaN
# 2052                          University of Minnesota        NaN  NaN     NaN
# 2053                              Columbia University        NaN  NaN     NaN
# 2054                                             None        NaN  NaN     NaN
# 2055                         University of California        NaN  NaN     NaN
# 2056                    University of Texas at Austin        NaN  NaN     NaN
# 2057                         University of California        NaN  NaN     NaN
# 2058                         University of New Mexico        NaN  NaN     NaN
# 2059                                             None        NaN  NaN     NaN
# 2060       University of Illinois at Urbana-Champaign        NaN  NaN     NaN
# 2061                            Georgetown University        NaN  NaN     NaN
# 2062                University of Southern California        NaN  NaN     NaN
# 2063                               Harvard University        NaN  NaN     NaN
# 2064                         University of California        NaN  NaN     NaN
# 2065                             University of Oxford        NaN  NaN     NaN
# 2066                              Stanford University        NaN  NaN     NaN
# 2067                                Tulane University        NaN  NaN     NaN
# 2068  Tulane University  \nWilliam R. Forstchen: 1950        NaN  NaN     NaN
# 2069                            University of Vermont        NaN  NaN     NaN
# 2070                      United States Naval Academy        NaN  NaN     NaN
# 2071                                  Barnard College        NaN  NaN     NaN
# 2072                           University of Maryland        NaN  NaN     NaN
# 2073                       Queen's University Belfast        NaN  NaN     NaN
# 2074                            University of Chicago        NaN  NaN     NaN
# 2075                             Bob Jones University        NaN  NaN     NaN
# 2076                            University of Arizona        NaN  NaN     NaN
# 2077                             Texas A&M University        NaN  NaN     NaN
# 2078                               Harvard University        NaN  NaN     NaN
# 2079                                             None        NaN  NaN     NaN
#
#      state city     _merge
# 2024   NaN  NaN  left_only
# 2025   NaN  NaN  left_only
# 2026   NaN  NaN  left_only
# 2027   NaN  NaN  left_only
# 2028   NaN  NaN  left_only
# 2029   NaN  NaN  left_only
# 2030   NaN  NaN  left_only
# 2031   NaN  NaN  left_only
# 2032   NaN  NaN  left_only
# 2033   NaN  NaN  left_only
# 2034   NaN  NaN  left_only
# 2035   NaN  NaN  left_only
# 2036   NaN  NaN  left_only
# 2037   NaN  NaN  left_only
# 2038   NaN  NaN  left_only
# 2039   NaN  NaN  left_only
# 2040   NaN  NaN  left_only
# 2041   NaN  NaN  left_only
# 2042   NaN  NaN  left_only
# 2043   NaN  NaN  left_only
# 2044   NaN  NaN  left_only
# 2045   NaN  NaN  left_only
# 2046   NaN  NaN  left_only
# 2047   NaN  NaN  left_only
# 2048   NaN  NaN  left_only
# 2049   NaN  NaN  left_only
# 2050   NaN  NaN  left_only
# 2051   NaN  NaN  left_only
# 2052   NaN  NaN  left_only
# 2053   NaN  NaN  left_only
# 2054   NaN  NaN  left_only
# 2055   NaN  NaN  left_only
# 2056   NaN  NaN  left_only
# 2057   NaN  NaN  left_only
# 2058   NaN  NaN  left_only
# 2059   NaN  NaN  left_only
# 2060   NaN  NaN  left_only
# 2061   NaN  NaN  left_only
# 2062   NaN  NaN  left_only
# 2063   NaN  NaN  left_only
# 2064   NaN  NaN  left_only
# 2065   NaN  NaN  left_only
# 2066   NaN  NaN  left_only
# 2067   NaN  NaN  left_only
# 2068   NaN  NaN  left_only
# 2069   NaN  NaN  left_only
# 2070   NaN  NaN  left_only
# 2071   NaN  NaN  left_only
# 2072   NaN  NaN  left_only
# 2073   NaN  NaN  left_only
# 2074   NaN  NaN  left_only
# 2075   NaN  NaN  left_only
# 2076   NaN  NaN  left_only
# 2077   NaN  NaN  left_only
# 2078   NaN  NaN  left_only
# 2079   NaN  NaN  left_only

# %%
auth_demo_birth.birth.unique()
# Out:
# array(['1877', '1879', '1892', '1873', '1875', '1867', '1882', '1885',
#        '1888', '1901', '1886', '1881', '1866', '1884', '1591', '1869',
#        '1876', '1894', '1902', '1896', '1895', '1947', '1880', '1893',
#        '1890', '1887', '1870', '1874', '1903', '1889', '1904', nan,
#        '1911', '1899', '1864', '1943', '1878', '1865', '1905', '1898',
#        '1900', '1763', '1914', '1908', '1916', '1897', '1891', '1871',
#        '1910', '1906', '1936', '1863', '1907', '1945', '1918', '1944',
#        '1946', '1757', '1970', '1883', '1909', '1981', '1912', '1992',
#        '1971', '1941', '1913', '1846', '1860', '1919', '1862', '1940',
#        '1915', '1924', '1859', '1929', '1980', '1977', '1952', '1935',
#        '1926', '1985', '1797', '1988', '1939', '1925', '1928', '1922',
#        '1923', '1850', '1917', '1921', '1858', '1793', '1951', '1835',
#        '1934', '1920', '1872', '1958', '1927', '1972', '1932', '1931',
#        '1938', '1959', '1933', '1956', '1990', '1930', '1856', '1942',
#        '1937', '1949', '1955', '1776', '1964', '1948', '1954', '1957',
#        '1960', '1963', '1786', '1950', '1962', '1953', '1832', '1965',
#        '1967', '1961', '1974', '1975', '1969', '1978', '1966', '1968',
#        '1976', '1979', 'Douglas Preston', '1973', 'J.A. Jance: 1944',
#        '1983', '1991', '1982', '1984', '1989', '1987', '1995', '1986',
#        '1993', '1994', '1779', 'Newt Gingrich: 1943'], dtype=object)

# %%
auth_demo_birth[auth_demo_birth.author == 'Douglas Preston']
# Out:
#                author            birth death race_eth  education  \
# 1544  Douglas Preston  Douglas Preston  1956      N/A  Caucasian
#
#             institution          birthplace                    temp country  \
# 1544  Bachelor's Degree  Cambridge, MA, USA  [Cambridge,  MA,  USA]     USA
#
#      state       city _merge
# 1544    MA  Cambridge   both

# %%
auth_demo_birth.birth = auth_demo_birth.birth.replace(r"Douglas Preston", "1956", regex = True)
auth_demo_birth.loc[1544, 'death'] = "N/A"
auth_demo_birth.loc[1544, 'race_eth'] = "Caucasian"
auth_demo_birth.loc[1544, 'education'] = "Bachelor's Degree"
auth_demo_birth.loc[1544, 'institution'] = "Pomona College"

# %%
auth_demo_birth[auth_demo_birth.author == "J.A. Jance"]
# Out:
#           author             birth death   race_eth          education  \
# 1694  J.A. Jance  J.A. Jance: 1944   N/A  Caucasian  Bachelor's Degree
#
#                 institution         birthplace                   temp country  \
# 1694  University of Arizona  Beaumont, TX, USA  [Beaumont,  TX,  USA]     USA
#
#      state      city _merge
# 1694    TX  Beaumont   both

# %%
auth_demo_birth.loc[1694, 'birth'] = "1944"

# %%
auth_demo_birth[auth_demo_birth.birth == "Newt Gingrich: 1943"]
# Out:
#                                    author                birth death race_eth  \
# 2068  Newt Gingrich, William R. Forstchen  Newt Gingrich: 1943   N/A    White
#
#      education                                      institution birthplace  \
# 2068     Ph.D.  Tulane University  \nWilliam R. Forstchen: 1950        NaN
#
#      temp country state city     _merge
# 2068  NaN     NaN   NaN  NaN  left_only

# %%
auth_demo_birth[auth_demo_birth.birth == "1779"]
# Out:
#              author birth death race_eth education institution birthplace  \
# 2034  Clement Moore  1779  1863    White      None        None        NaN
#
#      temp country state city     _merge
# 2034  NaN     NaN   NaN  NaN  left_only

# %%
auth_demo_birth.birth.unique()
# Out:
# array(['1877', '1879', '1892', '1873', '1875', '1867', '1882', '1885',
#        '1888', '1901', '1886', '1881', '1866', '1884', '1591', '1869',
#        '1876', '1894', '1902', '1896', '1895', '1947', '1880', '1893',
#        '1890', '1887', '1870', '1874', '1903', '1889', '1904', nan,
#        '1911', '1899', '1864', '1943', '1878', '1865', '1905', '1898',
#        '1900', '1763', '1914', '1908', '1916', '1897', '1891', '1871',
#        '1910', '1906', '1936', '1863', '1907', '1945', '1918', '1944',
#        '1946', '1757', '1970', '1883', '1909', '1981', '1912', '1992',
#        '1971', '1941', '1913', '1846', '1860', '1919', '1862', '1940',
#        '1915', '1924', '1859', '1929', '1980', '1977', '1952', '1935',
#        '1926', '1985', '1797', '1988', '1939', '1925', '1928', '1922',
#        '1923', '1850', '1917', '1921', '1858', '1793', '1951', '1835',
#        '1934', '1920', '1872', '1958', '1927', '1972', '1932', '1931',
#        '1938', '1959', '1933', '1956', '1990', '1930', '1856', '1942',
#        '1937', '1949', '1955', '1776', '1964', '1948', '1954', '1957',
#        '1960', '1963', '1786', '1950', '1962', '1953', '1832', '1965',
#        '1967', '1961', '1974', '1975', '1969', '1978', '1966', '1968',
#        '1976', '1979', '1973', '1983', '1991', '1982', '1984', '1989',
#        '1987', '1995', '1986', '1993', '1994', '1779',
#        'Newt Gingrich: 1943'], dtype=object)

# %%
auth_demo_birth.death.unique()
# Out:
# array(['1950', '1961', '1973', '1947', '1933', '1956', '1968', '1965',
#        '1963', '1946', '1960', '1966', '1954', '1674', '1957', '1958',
#        '1959', '1970', 'N/A', '1981', '1972', '1978', '1953', '1984',
#        '1944', '1974', '1945', '1941', '1977', '1934', '1990', '1951',
#        '1939', '1985', '1991', 'None', '1949', '1962', '1967', '1976',
#        '2010', '1942', '1940', '1975', '1943', '1992', '1955', '1964',
#        '1855', '1989', '2011', '1938', '1952', '1987', '1935', '1948',
#        '2003', '2018', '1983', '1998', '1996', '2008', '1993', '1986',
#        '1980', '1827', '2002', '1994', '2009', '2019', '2015', '2001',
#        '1915', '1982', '1997', '2005', '1926', '1912', '1971', '1979',
#        '1988', '1995', '1969', '1916', '199 Hodgins', '195 Lewisohn',
#        '1869', '2012', '2007', '2016', '1999', '1932', '2006', '1860',
#        '1936', '2013', '1874', '2017', '2000', '2004', '1931', '1902',
#        '2014', '1930', '2021', '2020', '2022', '1822', '1859', '2023',
#        '1888', '1929', '1863'], dtype=object)

# %%
auth_demo_birth[auth_demo_birth.author == 'Eric Hodgins']
# Out:
#            author birth        death race_eth          education  \
# 371  Eric Hodgins  1906  199 Hodgins    White  Bachelor's Degree
#
#             institution       birthplace                 temp country state  \
# 371  Harvard University  Newark, NJ, USA  [Newark,  NJ,  USA]     USA    NJ
#
#        city _merge
# 371  Newark   both

# %%
auth_demo_birth.loc[371, 'death'] = "1971"

# %%
auth_demo_birth[auth_demo_birth.death == ' 195 Lewisohn']
# Out:
# Empty DataFrame
# Columns: [author, birth, death, race_eth, education, institution, birthplace, temp, country, state, city, _merge]
# Index: []

# %%
auth_demo_birth.loc[388, 'death'] = "1955"

# %%
auth_demo_birth.education.unique()
# Out:
# array(['None', 'Graduate', 'Bachelors ', 'N/A', 'High School', 'MD', 'JD'],
#       dtype=object)

# %%
## Collapsing

# %%
auth_demo_birth.education = auth_demo_birth.education.replace(r"Ph\.D\.|Doctorate|Doctoral Degree|Doctor of Sacred Theology|PhD|Medical Degree|Doctor of Medicine|Doctor of Medicine \(MD\)|MD \(MD\)", "Graduate", regex = True)
auth_demo_birth.education = auth_demo_birth.education.replace(r"Bachelor’s Degree|Bachelor's Degree", "Undergrad ", regex = True)
auth_demo_birth.education = auth_demo_birth.education.replace(r"Medical Degree|Doctor of Medicine|Doctor of Medicine \(MD\)|MD \(MD\)", "MD", regex = True)
auth_demo_birth.education = auth_demo_birth.education.replace(r"Juris Doctor|J/.D/. Degree|J.D. Degree|J.D.", r"JD", regex = True)
auth_demo_birth.education = auth_demo_birth.education.replace(r"Degree in Modern Languages|MFA|Master's Degree|Master’s Degree|Graduate Degree|Masters", "Graduate", regex = True)
auth_demo_birth.education = auth_demo_birth.education.replace(r"Some college|High School Diploma", r"High School", regex = True)
